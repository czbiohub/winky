# %%
spades = '/Users/olgabot/anaconda3/envs/winky/bin/spades.py'

# %%
! $spades
# Out:
# SPAdes genome assembler v3.11.0
#
# Usage: /Users/olgabot/anaconda3/envs/winky/bin/spades.py [options] -o <output_dir>
#
# Basic options:
# -o	<output_dir>	directory to store all the resulting files (required)
# --sc			this flag is required for MDA (single-cell) data
# --meta			this flag is required for metagenomic sample data
# --rna			this flag is required for RNA-Seq data
# --plasmid		runs plasmidSPAdes pipeline for plasmid detection
# --iontorrent		this flag is required for IonTorrent data
# --test			runs SPAdes on toy dataset
# -h/--help		prints this usage message
# -v/--version		prints version
#
# Input data:
# --12	<filename>	file with interlaced forward and reverse paired-end reads
# -1	<filename>	file with forward paired-end reads
# -2	<filename>	file with reverse paired-end reads
# -s	<filename>	file with unpaired reads
# --pe<#>-12	<filename>	file with interlaced reads for paired-end library number <#> (<#> = 1,2,..,9)
# ...

# %%
! $spades --sanger ZN-1_ZNif1__2017-06-07_B01.ab1 --sanger ZN-1_ZNir1__2017-06-07_E01.ab1 -o spades-ZN-1
# Out:
# == Error ==  file with reads has unsupported format (only .fq, .fastq, .bam, .fa, .fasta, .fq.gz, .fastq.gz, .bam.gz, .fa.gz, .fasta.gz are supported): /Users/olgabot/code/winky/notebooks/ZN-1_ZNif1__2017-06-07_B01.ab1 (single reads, library number: 1, library type: sanger)
#
# In case you have troubles running SPAdes, you can write to spades.support@cab.spbu.ru
# or report an issue on our GitHub repository github.com/ablab/spades
# Please provide us with params.txt and spades.log files from the output directory.

# %%
! $spades --12 ../winky/test/data/ZN-1-concatenated.fastq -o spades-ZN-1
# Out:
# Command line: /Users/olgabot/anaconda3/envs/winky/bin/spades.py	--12	/Users/olgabot/code/winky/winky/test/data/ZN-1-concatenated.fastq	-o	/Users/olgabot/code/winky/notebooks/spades-ZN-1
#
# System information:
#   SPAdes version: 3.11.0
#   Python version: 3.5.2
#   OS: Darwin-16.7.0-x86_64-i386-64bit
#
# Output dir: /Users/olgabot/code/winky/notebooks/spades-ZN-1
# Mode: read error correction and assembling
# Debug mode is turned OFF
#
# Dataset parameters:
#   Multi-cell mode (you should set '--sc' flag if input data was obtained with MDA (single-cell) technology or --meta flag if processing metagenomic dataset)
#   Reads:
#     Library number: 1, library type: paired-end
#       orientation: fr
#       left reads: not specified
#       right reads: not specified
#       interlaced reads: ['/Users/olgabot/code/winky/winky/test/data/ZN-1-concatenated.fastq']
#       single reads: not specified
# Read error correction parameters:
#   Iterations: 1
# ...

# %%
! $spades --plasmid --12 ../winky/test/data/ZN-1-concatenated.fastq -o spades-ZN-1-plasmid
# Out:
# Command line: /Users/olgabot/anaconda3/envs/winky/bin/spades.py	--plasmid	--12	/Users/olgabot/code/winky/winky/test/data/ZN-1-concatenated.fastq	-o	/Users/olgabot/code/winky/notebooks/spades-ZN-1-plasmid
#
# System information:
#   SPAdes version: 3.11.0
#   Python version: 3.5.2
#   OS: Darwin-16.7.0-x86_64-i386-64bit
#
# Output dir: /Users/olgabot/code/winky/notebooks/spades-ZN-1-plasmid
# Mode: read error correction and assembling
# Debug mode is turned OFF
#
# Dataset parameters:
#   Multi-cell mode (you should set '--sc' flag if input data was obtained with MDA (single-cell) technology or --meta flag if processing metagenomic dataset)
#   Reads:
#     Library number: 1, library type: paired-end
#       orientation: fr
#       left reads: not specified
#       right reads: not specified
#       interlaced reads: ['/Users/olgabot/code/winky/winky/test/data/ZN-1-concatenated.fastq']
#       single reads: not specified
# Read error correction parameters:
#   Iterations: 1
# ...

# %%
! $spades --debug --plasmid --12 ../winky/test/data/ZN-1-concatenated.fastq -o spades-ZN-1-plasmid
# Out:
# Command line: /Users/olgabot/anaconda3/envs/winky/bin/spades.py	--debug	--plasmid	--12	/Users/olgabot/code/winky/winky/test/data/ZN-1-concatenated.fastq	-o	/Users/olgabot/code/winky/notebooks/spades-ZN-1-plasmid
#
# System information:
#   SPAdes version: 3.11.0
#   Python version: 3.5.2
#   OS: Darwin-16.7.0-x86_64-i386-64bit
#
# Output dir: /Users/olgabot/code/winky/notebooks/spades-ZN-1-plasmid
# Mode: read error correction and assembling
# Debug mode is turned ON
#
# Dataset parameters:
#   Multi-cell mode (you should set '--sc' flag if input data was obtained with MDA (single-cell) technology or --meta flag if processing metagenomic dataset)
#   Reads:
#     Library number: 1, library type: paired-end
#       orientation: fr
#       left reads: not specified
#       right reads: not specified
#       interlaced reads: ['/Users/olgabot/code/winky/winky/test/data/ZN-1-concatenated.fastq']
#       single reads: not specified
# Read error correction parameters:
#   Iterations: 1
# ...

# %%
ls -lha /Users/olgabot/code/winky/notebooks/spades-ZN-1/
# Out:
# total 72
# drwxr-xr-x  12 olgabot  staff   408B Sep 15 15:36 ./
# drwxr-xr-x@ 31 olgabot  staff   1.0K Sep 15 15:38 ../
# drwxr-xr-x   5 olgabot  staff   170B Sep 15 15:36 .bin_reads/
# drwxr-xr-x   3 olgabot  staff   102B Sep 15 15:36 K21/
# drwxr-xr-x   7 olgabot  staff   238B Sep 15 15:36 configs/
# drwxr-xr-x   7 olgabot  staff   238B Sep 15 15:36 corrected/
# -rw-r--r--   1 olgabot  staff    79B Sep 15 15:36 dataset.info
# -rw-r--r--   1 olgabot  staff   262B Sep 15 15:36 input_dataset.yaml
# -rw-r--r--   1 olgabot  staff   1.3K Sep 15 15:36 params.txt
# -rw-r--r--   1 olgabot  staff    21K Sep 15 15:36 spades.log
# drwxr-xr-x   4 olgabot  staff   136B Sep 15 15:36 split_input/
# drwxr-xr-x   2 olgabot  staff    68B Sep 15 15:36 tmp/

# %%
ls -lha /Users/olgabot/code/winky/notebooks/spades-ZN-1/split_input
# Out:
# total 16
# drwxr-xr-x   4 olgabot  staff   136B Sep 15 15:36 ./
# drwxr-xr-x  12 olgabot  staff   408B Sep 15 15:36 ../
# -rw-r--r--   1 olgabot  staff   3.7K Sep 15 15:36 ZN-1-concatenated_1.fastq
# -rw-r--r--   1 olgabot  staff   3.8K Sep 15 15:36 ZN-1-concatenated_2.fastq

# %%
! wc -l /Users/olgabot/code/winky/notebooks/spades-ZN-1/split_input/*
# Out:
#        8 /Users/olgabot/code/winky/notebooks/spades-ZN-1/split_input/ZN-1-concatenated_1.fastq
#        8 /Users/olgabot/code/winky/notebooks/spades-ZN-1/split_input/ZN-1-concatenated_2.fastq
#       16 total

# %%
! head /Users/olgabot/code/winky/notebooks/spades-ZN-1/split_input/*
# Out:
# ==> /Users/olgabot/code/winky/notebooks/spades-ZN-1/split_input/ZN-1-concatenated_1.fastq <==
# @ZN-1_ZNif1_
# ...
# +
# ...

# %%
ls ../winky/test/data/
# Out:
# ZN-1-concatenated.fastq             ZN-2_ZNif1__2017-06-07_C01.ab1*
# ZN-1_ZNif1__2017-06-07_B01.ab1*     ZN-2_ZNir1__2017-06-07_F01.ab1*
# ZN-1_ZNif1__2017-06-07_B01.fastq    ZN-2_pCAGGSf__2017-05-31_B06.ab1*
# ZN-1_ZNir1__2017-06-07_E01.ab1*     ZN-2_pCAGGSr__2017-05-31_H03.ab1*
# ZN-1_ZNir1__2017-06-07_E01.fastq    ZN-3_ZNif1__2017-06-07_D01.ab1*
# ZN-1_pCAGGSf__2017-05-31_A06.ab1*   ZN-3_ZNir1__2017-06-07_G01.ab1*
# ZN-1_pCAGGSf__2017-05-31_A06.fastq  ZN-3_pCAGGSf__2017-05-31_C06.ab1*
# ZN-1_pCAGGSr__2017-05-31_G03.ab1*   ZN-3_pCAGGSr__2017-05-31_A04.ab1*
# ZN-1_pCAGGSr__2017-05-31_G03.fastq

# %%
! $spades --cov-cutoff off --debug --plasmid --12 ../winky/test/data/ZN-1-concatenated.fastq -o spades-ZN-1-plasmid
# Out:
# Command line: /Users/olgabot/anaconda3/envs/winky/bin/spades.py	--cov-cutoff	off	--debug	--plasmid	--12	/Users/olgabot/code/winky/winky/test/data/ZN-1-concatenated.fastq	-o	/Users/olgabot/code/winky/notebooks/spades-ZN-1-plasmid
#
# System information:
#   SPAdes version: 3.11.0
#   Python version: 3.5.2
#   OS: Darwin-16.7.0-x86_64-i386-64bit
#
# Output dir: /Users/olgabot/code/winky/notebooks/spades-ZN-1-plasmid
# Mode: read error correction and assembling
# Debug mode is turned ON
#
# Dataset parameters:
#   Multi-cell mode (you should set '--sc' flag if input data was obtained with MDA (single-cell) technology or --meta flag if processing metagenomic dataset)
#   Reads:
#     Library number: 1, library type: paired-end
#       orientation: fr
#       left reads: not specified
#       right reads: not specified
#       interlaced reads: ['/Users/olgabot/code/winky/winky/test/data/ZN-1-concatenated.fastq']
#       single reads: not specified
# Read error correction parameters:
# ...
